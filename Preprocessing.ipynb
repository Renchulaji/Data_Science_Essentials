# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'/Users/renchulaji/Desktop/Data Science/House_Pricing.csv')

# %%
data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
Duplicate = data.duplicated()

# %%
print(Duplicate.sum())
# Out:
# 0

# %%
data = data.drop("ID",axis=1)
data = data.drop("Zipcode",axis=1)
data = data.drop("Latitude",axis=1)
data = data.drop("Longitude",axis=1)
data
# Out:
#       Date House was Sold  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0         14 October 2017    221900.0               3             1.00
# 1        14 December 2017    538000.0               3             2.25
# 2        15 February 2016    180000.0               2             1.00
# 3        14 December 2017    604000.0               4             3.00
# 4        15 February 2016    510000.0               3             2.00
# ...                   ...         ...             ...              ...
# 21608         14 May 2017    360000.0               3             2.50
# 21609    15 February 2016    400000.0               4             2.50
# 21610        14 June 2017    402101.0               2             0.75
# 21611     15 January 2016    400000.0               3             2.50
# 21612     14 October 2017    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# ...

# %%
data.isna().sum()
# Out:
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Living Area after Renovation (in Sqft)           1
# Lot Area after Renovation (in Sqft)              0
# dtype: int64

# %%
numerical_data=data.select_dtypes(include="number")
numerical_data
# Out:
#        Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0        221900.0               3             1.00               1180.0
# 1        538000.0               3             2.25               2570.0
# 2        180000.0               2             1.00                770.0
# 3        604000.0               4             3.00               1960.0
# 4        510000.0               3             2.00               1680.0
# ...           ...             ...              ...                  ...
# 21608    360000.0               3             2.50               1530.0
# 21609    400000.0               4             2.50               2310.0
# 21610    402101.0               2             0.75               1020.0
# 21611    400000.0               3             2.50               1600.0
# 21612    325000.0               2             0.75               1020.0
#
#        Lot Area (in Sqft)  No of Floors  Overall Grade  \
# ...

# %%
Categorical_data=data.select_dtypes(include="object")
Categorical_data
# Out:
#       Date House was Sold Waterfront View No of Times Visited  \
# 0         14 October 2017              No                 NaN
# 1        14 December 2017              No                 NaN
# 2        15 February 2016              No                 NaN
# 3        14 December 2017              No                 NaN
# 4        15 February 2016              No                 NaN
# ...                   ...             ...                 ...
# 21608         14 May 2017              No                 NaN
# 21609    15 February 2016              No                 NaN
# 21610        14 June 2017              No                 NaN
# 21611     15 January 2016              No                 NaN
# 21612     14 October 2017              No                 NaN
#
#       Condition of the House
# 0                       Fair
# 1                       Fair
# 2                       Fair
# 3                  Excellent
# 4                       Fair
# ...                      ...
# ...

# %%
num_cols=numerical_data.columns.tolist()
print(num_cols)
cat_cols=Categorical_data.columns.tolist()
print(cat_cols)
# Out:
# ['Sale Price', 'No of Bedrooms', 'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)', 'No of Floors', 'Overall Grade', 'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)', 'Age of House (in Years)', 'Renovated Year', 'Living Area after Renovation (in Sqft)', 'Lot Area after Renovation (in Sqft)']
# ['Date House was Sold', 'Waterfront View', 'No of Times Visited', 'Condition of the House']

# %%
for col in num_cols: 
    plt.hist(numerical_data[col])
    plt.title("Histogram of {} column".format(col))
    plt.xlabel(col)
    plt.ylabel("count")
    plt.show()

# %%
mean_data = data[["No of Bathrooms","Overall Grade","Living Area after Renovation (in Sqft)"]]
mean_cols = mean_data.columns.tolist()

# %%
mean_data.isna().sum()
# Out:
# No of Bathrooms                           0
# Overall Grade                             0
# Living Area after Renovation (in Sqft)    0
# dtype: int64

# %%
median_data = data[["Sale Price","Flat Area (in Sqft)","Lot Area (in Sqft)","Area of the House from Basement (in Sqft)"]]

# %%
median_cols = median_data.columns.tolist()

# %%
median_data.isna().sum()
# Out:
# Sale Price                                   0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# Area of the House from Basement (in Sqft)    0
# dtype: int64

# %%
numerical_data.isna().sum()
# Out:
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
remaining_data = data[["No of Bedrooms", "No of Floors", "Basement Area (in Sqft)","Age of House (in Years)","Renovated Year"]]
remaining_cols = remaining_data.columns.tolist()

# %%
remaining_data
# Out:
#        No of Bedrooms  No of Floors  Basement Area (in Sqft)  \
# 0                   3           1.0                        0
# 1                   3           2.0                      400
# 2                   2           1.0                        0
# 3                   4           1.0                      910
# 4                   3           1.0                        0
# ...               ...           ...                      ...
# 21608               3           3.0                        0
# 21609               4           2.0                        0
# 21610               2           2.0                        0
# 21611               3           2.0                        0
# 21612               2           2.0                        0
#
#        Age of House (in Years)  Renovated Year
# 0                           63               0
# 1                           67            1991
# 2                           85               0
# ...

# %%
data = pd.concat([mean_data,median_data,remaining_data],axis=1)
data
# Out:
#        No of Bathrooms  Overall Grade  Living Area after Renovation (in Sqft)  \
# 0                 1.00              7                                  1340.0
# 1                 2.25              7                                  1690.0
# 2                 1.00              6                                  2720.0
# 3                 3.00              7                                  1360.0
# 4                 2.00              8                                  1800.0
# ...                ...            ...                                     ...
# 21608             2.50              8                                  1530.0
# 21609             2.50              8                                  1830.0
# 21610             0.75              7                                  1020.0
# 21611             2.50              8                                  1410.0
# 21612             0.75              7                                  1020.0
#
# ...

# %%
data.isna().sum()
# Out:
# No of Bathrooms                              0
# Overall Grade                                0
# Living Area after Renovation (in Sqft)       0
# Sale Price                                   0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# Area of the House from Basement (in Sqft)    0
# No of Bedrooms                               0
# No of Floors                                 0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# dtype: int64

# %%
data
# Out:
#        No of Bathrooms  Overall Grade  Living Area after Renovation (in Sqft)  \
# 0                 1.00              7                                  1340.0
# 1                 2.25              7                                  1690.0
# 2                 1.00              6                                  2720.0
# 3                 3.00              7                                  1360.0
# 4                 2.00              8                                  1800.0
# ...                ...            ...                                     ...
# 21608             2.50              8                                  1530.0
# 21609             2.50              8                                  1830.0
# 21610             0.75              7                                  1020.0
# 21611             2.50              8                                  1410.0
# 21612             0.75              7                                  1020.0
#
# ...

# %%
Categorical_data.isna().sum()
# Out:
# Date House was Sold           0
# Waterfront View               0
# No of Times Visited       19489
# Condition of the House        0
# dtype: int64

# %%
for col in cat_cols:
    Categorical_data[col] = Categorical_data[col].fillna(Categorical_data[col].mode()[0])

# %%
Categorical_data.isna().sum()
# Out:
# Date House was Sold       0
# Waterfront View           0
# No of Times Visited       0
# Condition of the House    0
# dtype: int64

# %%
data = pd.concat([Categorical_data,mean_data,median_data,remaining_data],axis=1)

# %%
data
# Out:
#       Date House was Sold Waterfront View No of Times Visited  \
# 0         14 October 2017              No               Twice
# 1        14 December 2017              No               Twice
# 2        15 February 2016              No               Twice
# 3        14 December 2017              No               Twice
# 4        15 February 2016              No               Twice
# ...                   ...             ...                 ...
# 21608         14 May 2017              No               Twice
# 21609    15 February 2016              No               Twice
# 21610        14 June 2017              No               Twice
# 21611     15 January 2016              No               Twice
# 21612     14 October 2017              No               Twice
#
#       Condition of the House  No of Bathrooms  Overall Grade  \
# 0                       Fair             1.00              7
# 1                       Fair             2.25              7
# ...

# %%
num_scale = data.drop(['Sale Price','Date House was Sold','Waterfront View','No of Times Visited','Condition of the House'],axis=1)

# %%
num_scale.columns
# Out:
# Index(['No of Bathrooms', 'Overall Grade',
#        'Living Area after Renovation (in Sqft)', 'Flat Area (in Sqft)',
#        'Lot Area (in Sqft)', 'Area of the House from Basement (in Sqft)',
#        'No of Bedrooms', 'No of Floors', 'Basement Area (in Sqft)',
#        'Age of House (in Years)', 'Renovated Year'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
num_df_std_scaled = std_scaler.fit_transform(num_scale)

# %%
num_df_std_scaled
# Out:
# array([[-1.44761165, -0.56401269, -0.94333939, ..., -0.65868104,
#          0.54489777, -0.21012839],
#        [ 0.17566112, -0.56401269, -0.43266821, ...,  0.2451414 ,
#          0.6810785 ,  4.7466776 ],
#        [-1.44761165, -1.46865138,  1.0701641 , ..., -0.65868104,
#          1.29389179, -0.21012839],
#        ...,
#        [-1.7722662 , -0.56401269, -1.41023875, ..., -0.65868104,
#         -1.29354209, -0.21012839],
#        [ 0.50031567,  0.340626  , -0.84120515, ..., -0.65868104,
#         -1.12331618, -0.21012839],
#        [-1.7722662 , -0.56401269, -1.41023875, ..., -0.65868104,
#         -1.25949691, -0.21012839]])

# %%
df_std_scaled = pd.DataFrame(num_df_std_scaled, columns=num_scale.columns)
df_std_scaled
# Out:
#        No of Bathrooms  Overall Grade  Living Area after Renovation (in Sqft)  \
# 0            -1.447612      -0.564013                               -0.943339
# 1             0.175661      -0.564013                               -0.432668
# 2            -1.447612      -1.468651                                1.070164
# 3             1.149625      -0.564013                               -0.914158
# 4            -0.148993       0.340626                               -0.272172
# ...                ...            ...                                     ...
# 21608         0.500316       0.340626                               -0.666118
# 21609         0.500316       0.340626                               -0.228400
# 21610        -1.772266      -0.564013                               -1.410239
# 21611         0.500316       0.340626                               -0.841205
# 21612        -1.772266      -0.564013                               -1.410239
#
# ...

# %%
Categorical_data
# Out:
#       Date House was Sold Waterfront View No of Times Visited  \
# 0         14 October 2017              No               Twice
# 1        14 December 2017              No               Twice
# 2        15 February 2016              No               Twice
# 3        14 December 2017              No               Twice
# 4        15 February 2016              No               Twice
# ...                   ...             ...                 ...
# 21608         14 May 2017              No               Twice
# 21609    15 February 2016              No               Twice
# 21610        14 June 2017              No               Twice
# 21611     15 January 2016              No               Twice
# 21612     14 October 2017              No               Twice
#
#       Condition of the House
# 0                       Fair
# 1                       Fair
# 2                       Fair
# 3                  Excellent
# 4                       Fair
# ...                      ...
# ...

# %%
cat_encode = Categorical_data.drop(["Date House was Sold"],axis=1)

# %%
cat_encode
# Out:
#       Waterfront View No of Times Visited Condition of the House
# 0                  No               Twice                   Fair
# 1                  No               Twice                   Fair
# 2                  No               Twice                   Fair
# 3                  No               Twice              Excellent
# 4                  No               Twice                   Fair
# ...               ...                 ...                    ...
# 21608              No               Twice                   Fair
# 21609              No               Twice                   Fair
# 21610              No               Twice                   Fair
# 21611              No               Twice                   Fair
# 21612              No               Twice                   Fair
#
# [21613 rows x 3 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
encoded_data = encoder.fit_transform(cat_encode[['Waterfront View']])
one_hot_encoded_df = pd.DataFrame(encoded_data,
columns=encoder.get_feature_names_out(['Waterfront View']))

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
cat_encode['No of Times Visited_label_encoded'] = label_encoder.fit_transform(cat_encode['No of Times Visited'])
cat_encode
# Out:
#       Waterfront View No of Times Visited Condition of the House  \
# 0                  No               Twice                   Fair
# 1                  No               Twice                   Fair
# 2                  No               Twice                   Fair
# 3                  No               Twice              Excellent
# 4                  No               Twice                   Fair
# ...               ...                 ...                    ...
# 21608              No               Twice                   Fair
# 21609              No               Twice                   Fair
# 21610              No               Twice                   Fair
# 21611              No               Twice                   Fair
# 21612              No               Twice                   Fair
#
#        No of Times Visited_label_encoded
# 0                                      3
# 1                                      3
# 2                                      3
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
cat_encode['Condition of the House_label_encoded'] = label_encoder.fit_transform(cat_encode['Condition of the House'])
cat_encode
# Out:
#       Waterfront View No of Times Visited Condition of the House  \
# 0                  No               Twice                   Fair
# 1                  No               Twice                   Fair
# 2                  No               Twice                   Fair
# 3                  No               Twice              Excellent
# 4                  No               Twice                   Fair
# ...               ...                 ...                    ...
# 21608              No               Twice                   Fair
# 21609              No               Twice                   Fair
# 21610              No               Twice                   Fair
# 21611              No               Twice                   Fair
# 21612              No               Twice                   Fair
#
#        No of Times Visited_label_encoded  Condition of the House_label_encoded
# 0                                      3                                     2
# ...

# %%
cat_encode = pd.concat([one_hot_encoded_df,cat_encode],axis=1)

# %%
cat_encode
# Out:
#        Waterfront View_No  Waterfront View_Yes Waterfront View  \
# 0                     1.0                  0.0              No
# 1                     1.0                  0.0              No
# 2                     1.0                  0.0              No
# 3                     1.0                  0.0              No
# 4                     1.0                  0.0              No
# ...                   ...                  ...             ...
# 21608                 1.0                  0.0              No
# 21609                 1.0                  0.0              No
# 21610                 1.0                  0.0              No
# 21611                 1.0                  0.0              No
# 21612                 1.0                  0.0              No
#
#       No of Times Visited Condition of the House  \
# 0                   Twice                   Fair
# 1                   Twice                   Fair
# 2                   Twice                   Fair
# ...
